# %% [markdown]
# # Retail Sales Analytics Tutorial
#
# This beginner-friendly notebook walks through the complete Python pipeline: loading the CSV, cleaning data, creating features, running EDA, and saving charts. Run `pip install -r requirements.txt` before starting.

# %% [markdown]
# ## 1. Import libraries and project modules

# %%
from pathlib import Path
import sys
PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.insert(0, str(PROJECT_ROOT / 'src'))

from retail_analytics.data_cleaning import read_csv, inspect_dataset, describe_columns, clean_data
from retail_analytics.eda import run_complete_eda
from retail_analytics.visualizations import create_all_charts

# %% [markdown]
# ## 2. Load and inspect the dataset
# The pipeline automatically looks for a CSV in `data/raw/`. The inspection output tells us how many rows and columns exist, the data types, missing values, and duplicates.

# %%
raw_df = read_csv()
inspection = inspect_dataset(raw_df)
inspection

# %% [markdown]
# ## 3. Understand every column in simple English

# %%
describe_columns(raw_df)

# %% [markdown]
# ## 4. Clean the data
# Cleaning removes duplicates, fills missing text and numeric values, converts dates, and creates Year, Month, Quarter, Profit Margin, and Shipping Days features.

# %%
cleaned_df = clean_data(raw_df)
cleaned_df.head()

# %% [markdown]
# ## 5. Run complete EDA
# These outputs cover revenue, profit, orders, monthly trends, product/category performance, customer performance, discounts, margins, and shipping.

# %%
eda_results = run_complete_eda(cleaned_df)
eda_results['kpis']

# %%
eda_results['monthly_trends'].head()

# %%
eda_results['top_10_products']

# %% [markdown]
# ## 6. Generate charts
# All charts are saved into the `images/` folder with clear titles and labels.

# %%
chart_paths = create_all_charts(eda_results)
chart_paths

# %% [markdown]
# ## 7. Save cleaned data and EDA outputs
# For automated execution, run this command from the repository root:
#
# ```bash
# python scripts/run_pipeline.py
# ```
